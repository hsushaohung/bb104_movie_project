# %%
import pickle
with open('/Users/mac/Desktop/BB104/專題/dbscan/data/movie_data.pkl',"rb") as f:
    movie_data = pickle.load(f)
movie_data[:1]
# Out:
# [{'chname': '萬世魔星',
#   'enname': 'Life of Brian',
#   'genres': ['Comedy'],
#   'imdb_id': 'tt0079470',
#   'noComments': 1,
#   'rel': [0.02825,
#    0.02925,
#    0.038250000000000006,
#    0.04199999999999998,
#    0.07324999999999998,
#    0.1735,
#    0.11,
#    0.21925,
#    0.10799999999999997,
#    0.05099999999999999,
#    0.017749999999999988,
#    0.024749999999999998,
#    0.10475,
#    0.007500000000000007,
#    0.00774999999999998,
#    0.067,
#    0.03849999999999998,
#    0.96825,
#    0.09100000000000004,
#    0.14275,
#    0.4015,
#    0.392,
#    0.02150000000000002,
#    0.006500000000000007,
#    0.15749999999999995,
#    0.12874999999999998,
#    0.08900000000000002,
#    0.21025,
#    0.14425,
#    0.43375,
#    0.028000000000000025,
#    0.17725000000000002,
#    0.22875,
#    0.07050000000000001,
#    0.054999999999999986,
#    0.12674999999999995,
#    0.07,
#    0.01050000000000001,
#    0.017000000000000015,
#    0.00924999999999998,
# ...

# %%
#movie_data[0]['tags']
#movie_data[0]['stop_words']
movie_data[0]['rel']
# Out:
# [0.02825,
#  0.02925,
#  0.038250000000000006,
#  0.04199999999999998,
#  0.07324999999999998,
#  0.1735,
#  0.11,
#  0.21925,
#  0.10799999999999997,
#  0.05099999999999999,
#  0.017749999999999988,
#  0.024749999999999998,
#  0.10475,
#  0.007500000000000007,
#  0.00774999999999998,
#  0.067,
#  0.03849999999999998,
#  0.96825,
#  0.09100000000000004,
#  0.14275,
#  0.4015,
#  0.392,
#  0.02150000000000002,
#  0.006500000000000007,
#  0.15749999999999995,
#  0.12874999999999998,
#  0.08900000000000002,
#  0.21025,
#  0.14425,
#  0.43375,
#  0.028000000000000025,
#  0.17725000000000002,
#  0.22875,
#  0.07050000000000001,
#  0.054999999999999986,
#  0.12674999999999995,
#  0.07,
#  0.01050000000000001,
#  0.017000000000000015,
#  0.00924999999999998,
#  0.020500000000000015,
#  0.0685,
#  0.09699999999999998,
#  0.02250000000000002,
#  0.17325000000000002,
#  0.59175,
#  0.01150000000000001,
#  0.15425,
#  0.21625,
#  0.1275,
#  0.10149999999999998,
#  0.1345,
# ...

# %%
type(str(movie_data[0]['rel'][0]))
# Out:
# str

# %%
data_list = []
movie_list = []

for i in movie_data:
    try:
        rel_list = []
        for j in i['rel']:
            rel_list.append(str(j))
        data_list.append(' '.join(rel_list)) #改！！！
        movie_list.append(i['chname'])
    except:
        pass

# %%
len(data_list)
#data_list
data_list[0]
# Out:
# '0.02825 0.02925 0.038250000000000006 0.04199999999999998 0.07324999999999998 0.1735 0.11 0.21925 0.10799999999999997 0.05099999999999999 0.017749999999999988 0.024749999999999998 0.10475 0.007500000000000007 0.00774999999999998 0.067 0.03849999999999998 0.96825 0.09100000000000004 0.14275 0.4015 0.392 0.02150000000000002 0.006500000000000007 0.15749999999999995 0.12874999999999998 0.08900000000000002 0.21025 0.14425 0.43375 0.028000000000000025 0.17725000000000002 0.22875 0.07050000000000001 0.054999999999999986 0.12674999999999995 0.07 0.01050000000000001 0.017000000000000015 0.00924999999999998 0.020500000000000015 0.0685 0.09699999999999998 0.02250000000000002 0.17325000000000002 0.59175 0.01150000000000001 0.15425 0.21625 0.1275 0.10149999999999998 0.1345 0.07874999999999999 0.15775 0.2295 0.015500000000000012 0.00924999999999998 0.0555 0.09175 0.04225000000000001 0.017500000000000016 0.05575000000000002 0.017749999999999988 0.04475000000000001 0.029000000000000026 0.01750000000
# ...

# %%
len(movie_list)
movie_list
# Out:
# ['萬世魔星',
#  '東方快車謀殺案',
#  '2001太空漫遊',
#  '機械生活',
#  '大都會',
#  '美人魚',
#  '哈姆雷特',
#  '單身動物園',
#  '流離者之歌',
#  '過客',
#  '你那邊幾點',
#  '輝耀姬物語',
#  '天注定',
#  '一代宗師',
#  '偷書賊',
#  '一一',
#  '超人：鋼鐵英雄',
#  '向政府說不',
#  '贖罪',
#  '地下鐵',
#  '普羅米修斯',
#  '咆哮山莊',
#  '黛絲姑娘',
#  '廣島之戀',
#  '127小時',
#  '告白',
#  '薩拉戈薩的手稿',
#  '阿凡達',
#  '復仇',
#  '東京奏鳴曲',
#  '赤色風暴',
#  '葉問',
#  '赤壁',
#  '長江7號',
#  '潛水鐘與蝴蝶',
#  '色，戒',
#  '男兒本色',
#  '變形金剛',
#  '跟蹤',
#  '滿城盡帶黃金甲',
#  '達文西密碼',
#  '天生一對',
#  '斷背山',
#  '霍元甲',
#  '金剛',
#  '2046',
#  '新警察故事',
#  '天地英雄',
#  '無間道II',
#  '無間道',
#  '異星入境',
#  '計程人生',
#  '七武士',
#  '腳踏車大作戰',
#  '醉鄉民謠',
#  '生存法則',
#  '歌劇魅影',
#  '賓漢',
#  '科學怪人',
#  '大飯店',
#  '舊金山',
#  '白雪公主',
#  '亂世佳人',
#  '綠野仙蹤',
#  '大獨裁者',
#  '小飛象',
#  '黃金時代',
#  '風雲人物',
#  '仙履奇緣',
#  '日落大道',
#  '愛麗絲夢遊仙境',
#  '花都舞影',
#  '日正當中',
#  '紅磨坊',
#  '萬花嬉春',
#  '恐怖蠟像館',
#  '羅馬假期',
#  '鐵達尼號',
#  '小牛',
#  '哥吉拉',
#  '後窗',
#  '逃亡',
#  '生死戀',
#  '巨人',
#  '決戰3:10',
#  '變蠅人',
#  '地心冒險',
#  '情聖',
#  '絕地7騎士',
#  '夜',
#  '瞞天過海',
#  '小兵',
# ...

# %%
import pandas as pd

df = pd.DataFrame(movie_list, columns = ['movie'])
df
# Out:
#              movie
# 0             萬世魔星
# 1          東方快車謀殺案
# 2         2001太空漫遊
# 3             機械生活
# 4              大都會
# 5              美人魚
# 6             哈姆雷特
# 7            單身動物園
# 8            流離者之歌
# 9               過客
# 10           你那邊幾點
# 11           輝耀姬物語
# 12             天注定
# 13            一代宗師
# 14             偷書賊
# 15              一一
# 16         超人：鋼鐵英雄
# 17           向政府說不
# 18              贖罪
# 19             地下鐵
# 20           普羅米修斯
# 21            咆哮山莊
# 22            黛絲姑娘
# 23            廣島之戀
# 24           127小時
# 25              告白
# 26         薩拉戈薩的手稿
# 27             阿凡達
# 28              復仇
# 29           東京奏鳴曲
# ...            ...
# 2045      戴珍珠耳環的少女
# 2046          K歌情人
# 2047          再見列寧
# 2048          奇異恩典
# 2049       老爸的單程車票
# 2050         拿破崙炸藥
# 2051     瞞天過海：十三王牌
# 2052          豆豆假期
# 2053        第六感追緝令
# 2054         人生駕駛課
# 2055          未來小子
# 2056          王牌對決
# 2057         夏綠蒂的網
# 2058          夢幻女郎
# 2059  特務風雲：中情局誕生秘辛
# ...

# %%
import copy
df_raw = copy.deepcopy(df)
df_raw
# Out:
#              movie
# 0             萬世魔星
# 1          東方快車謀殺案
# 2         2001太空漫遊
# 3             機械生活
# 4              大都會
# 5              美人魚
# 6             哈姆雷特
# 7            單身動物園
# 8            流離者之歌
# 9               過客
# 10           你那邊幾點
# 11           輝耀姬物語
# 12             天注定
# 13            一代宗師
# 14             偷書賊
# 15              一一
# 16         超人：鋼鐵英雄
# 17           向政府說不
# 18              贖罪
# 19             地下鐵
# 20           普羅米修斯
# 21            咆哮山莊
# 22            黛絲姑娘
# 23            廣島之戀
# 24           127小時
# 25              告白
# 26         薩拉戈薩的手稿
# 27             阿凡達
# 28              復仇
# 29           東京奏鳴曲
# ...            ...
# 2045      戴珍珠耳環的少女
# 2046          K歌情人
# 2047          再見列寧
# 2048          奇異恩典
# 2049       老爸的單程車票
# 2050         拿破崙炸藥
# 2051     瞞天過海：十三王牌
# 2052          豆豆假期
# 2053        第六感追緝令
# 2054         人生駕駛課
# 2055          未來小子
# 2056          王牌對決
# 2057         夏綠蒂的網
# 2058          夢幻女郎
# 2059  特務風雲：中情局誕生秘辛
# ...

# %% [markdown]
# # dbscan

# %%
from  sklearn.feature_extraction.text  import  CountVectorizer  

vectorizer = CountVectorizer()  
X = vectorizer.fit_transform(data_list)  
words = vectorizer.get_feature_names()
#print(len(words))
#print(words)
#print(len(X.toarray()))
#print(X.toarray())

from  sklearn.feature_extraction.text  import  TfidfTransformer  

transformer = TfidfTransformer()  
tfidf = transformer.fit_transform(X)
print(tfidf)

##print(words)
print(tfidf.toarray())
# Out:
#   (0, 111)	0.024315923909
#   (0, 115)	0.0360361436704
#   (0, 151)	0.0254730963191
#   (0, 166)	0.0260367124853
#   (0, 291)	0.0315737314504
#   (0, 692)	0.0257909008486
#   (0, 438)	0.0193886917081
#   (0, 874)	0.029146318207
#   (0, 430)	0.0379009480419
#   (0, 202)	0.0832881835903
#   (0, 69)	0.0584313739215
#   (0, 97)	0.0353985297871
#   (0, 417)	0.019288593816
#   (0, 28)	0.023931504566
#   (0, 29)	0.0478399148197
#   (0, 266)	0.0470939933121
#   (0, 152)	0.037895693843
#   (0, 3865)	0.0562559690911
#   (0, 362)	0.0549098237509
#   (0, 569)	0.0223928710865
#   (0, 1602)	0.0388840315752
#   (0, 1565)	0.0376861119444
#   (0, 84)	0.0234854997722
#   (0, 24)	0.0491280379852
#   (0, 628)	0.0464823457162
#   :	:
#   (2074, 3092)	0.0528552414256
#   (2074, 2316)	0.0905189656038
#   (2074, 1324)	0.0356651390435
#   (2074, 3176)	0.0513052452257
#   (2074, 3457)	0.0570754180126
#   (2074, 1621)	0.0393864909089
#   (2074, 3641)	0.0586856448872
#   (2074, 1653)	0.0399083503231
# ...

# %%
from sklearn.cluster import KMeans, MiniBatchKMeans,DBSCAN

#db = DBSCAN(n_jobs=-1,eps=0.01, min_samples=3,metric=mydistance)
#db = DBSCAN(n_jobs=-1,eps=0.7, min_samples=3,metric="euclidean") #

#db = DBSCAN(n_jobs=-1,eps=0.8, min_samples=3,metric="euclidean") #1
#db = DBSCAN(n_jobs=-1,eps=0.9, min_samples=3,metric="euclidean") #1
#db = DBSCAN(n_jobs=-1,eps=1, min_samples=3,metric="euclidean") #0

#db = DBSCAN(n_jobs=-1,eps=1.5, min_samples=3,metric="euclidean") #1

#db = DBSCAN(n_jobs=-1,eps=0.5, min_samples=5,metric="euclidean") #0
#db = DBSCAN(n_jobs=-1,eps=0.75, min_samples=5,metric="euclidean") #0
#db = DBSCAN(n_jobs=-1,eps=0.8, min_samples=5,metric="euclidean") #0
#db = DBSCAN(n_jobs=-1,eps=0.9, min_samples=5,metric="euclidean") #1
#db = DBSCAN(n_jobs=-1,eps=1, min_samples=5,metric="euclidean") #1
#db = DBSCAN(n_jobs=-1,eps=1.5, min_samples=5,metric="euclidean") #1
#db = DBSCAN(n_jobs=-1,eps=2, min_samples=5,metric="euclidean") #1

#db = DBSCAN(n_jobs=-1,eps=2, min_samples=50,metric="euclidean") #0
db = DBSCAN(n_jobs=-1,eps=0.5, min_samples=50,metric="euclidean") #1
#db = DBSCAN(n_jobs=-1,eps=10, min_samples=50,metric="euclidean") #1
#db = DBSCAN(n_jobs=-1,eps=20, min_samples=50,metric="euclidean") #1

#db = DBSCAN(n_jobs=-1,eps=0.7, min_samples=2,metric="euclidean") #
#db = DBSCAN(n_jobs=-1,eps=0.8, min_samples=2,metric="euclidean") #

# %%
#very slow

db.fit(tfidf.toarray())
# Out:
# DBSCAN(algorithm='auto', eps=0.5, leaf_size=30, metric='euclidean',
#     metric_params=None, min_samples=50, n_jobs=-1, p=None)

# %%
set(db.labels_)
# Out:
# {-1}

# %%
import numpy as np

core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask
# Out:
# array([False, False, False, ..., False, False, False], dtype=bool)

# %%
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_
labels
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
db.labels_
#len(db.labels_)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# 確認各個cluster有多少資料

# %%
import pandas as pd

#pd.Series(db.labels_)
df_raw["cluster"] = pd.Series(db.labels_)
df_raw
# Out:
#              movie  cluster_h  cluster
# 0             萬世魔星         -1        0
# 1          東方快車謀殺案         -1        0
# 2         2001太空漫遊         -1        0
# 3             機械生活         -1        0
# 4              大都會         -1        0
# 5              美人魚         -1        0
# 6             哈姆雷特         -1        0
# 7            單身動物園         -1        0
# 8            流離者之歌         -1        0
# 9               過客         -1        0
# 10           你那邊幾點         -1        0
# 11           輝耀姬物語         -1        0
# 12             天注定         -1        0
# 13            一代宗師         -1        0
# 14             偷書賊         -1        0
# 15              一一         -1        0
# 16         超人：鋼鐵英雄         -1        0
# 17           向政府說不         -1        0
# 18              贖罪         -1        0
# 19             地下鐵         -1        0
# 20           普羅米修斯         -1        0
# 21            咆哮山莊         -1        0
# 22            黛絲姑娘         -1        0
# ...

# %%
labels = list(set(db.labels_))
labels
# Out:
# [0]

# %%
sum = 0
for i in set(labels):
    findtag = (df_raw["cluster"] == labels[i])
    #sum += len(df_raw[findtag])
    print(len(df_raw[findtag]))
print(sum)
# Out:
# 2075
# 0

# %%
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_clusters_
# Out:
# 1

# %% [markdown]
# # h dbscan

# %%
# !pip install hdbscan
# Out:
# ...
#     100% |████████████████████████████████| 4.7MB 117kB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for hdbscan ... done
#   Stored in directory: /Users/mac/Library/Caches/pip/wheels/3c/66/6b/d47e0a5400f27f6cb22977e0e3c8826bc7e716c5b3f3ade0cb
# Successfully built hdbscan
# ...

# %%
import hdbscan
clusterer = hdbscan.HDBSCAN(min_cluster_size=50)
clusterer.fit(tfidf.toarray())
# Out:
# HDBSCAN(algorithm='best', allow_single_cluster=False, alpha=1.0,
#     approx_min_span_tree=True, cluster_selection_method='eom',
#     core_dist_n_jobs=4, gen_min_span_tree=False, leaf_size=40,
#     match_reference_implementation=False, memory=Memory(cachedir=None),
#     metric='euclidean', min_cluster_size=50, min_samples=None, p=None,
#     prediction_data=False)

# %%
clusterer.labels_
# Out:
# array([-1, -1, -1, ..., -1, -1, -1])

# %%
#finding the largest cluster label
clusterer.labels_.max()
# Out:
# -1

# %%
df_raw["cluster_h"] = pd.Series(clusterer.labels_)
df_raw
# Out:
#              movie  cluster_h  cluster
# 0             萬世魔星         -1        0
# 1          東方快車謀殺案         -1        0
# 2         2001太空漫遊         -1        0
# 3             機械生活         -1        0
# 4              大都會         -1        0
# 5              美人魚         -1        0
# 6             哈姆雷特         -1        0
# 7            單身動物園         -1        0
# 8            流離者之歌         -1        0
# 9               過客         -1        0
# 10           你那邊幾點         -1        0
# 11           輝耀姬物語         -1        0
# 12             天注定         -1        0
# 13            一代宗師         -1        0
# 14             偷書賊         -1        0
# 15              一一         -1        0
# 16         超人：鋼鐵英雄         -1        0
# 17           向政府說不         -1        0
# 18              贖罪         -1        0
# 19             地下鐵         -1        0
# 20           普羅米修斯         -1        0
# 21            咆哮山莊         -1        0
# 22            黛絲姑娘         -1        0
# ...

# %%
df_raw[df_raw["cluster_h"] == clusterer.labels_[1]]
# Out:
#              movie  cluster_h  cluster
# 0             萬世魔星         -1        0
# 1          東方快車謀殺案         -1        0
# 2         2001太空漫遊         -1        0
# 3             機械生活         -1        0
# 4              大都會         -1        0
# 5              美人魚         -1        0
# 6             哈姆雷特         -1        0
# 7            單身動物園         -1        0
# 8            流離者之歌         -1        0
# 9               過客         -1        0
# 10           你那邊幾點         -1        0
# 11           輝耀姬物語         -1        0
# 12             天注定         -1        0
# 13            一代宗師         -1        0
# 14             偷書賊         -1        0
# 15              一一         -1        0
# 16         超人：鋼鐵英雄         -1        0
# 17           向政府說不         -1        0
# 18              贖罪         -1        0
# 19             地下鐵         -1        0
# 20           普羅米修斯         -1        0
# 21            咆哮山莊         -1        0
# 22            黛絲姑娘         -1        0
# ...

# %%
labels = list(set(clusterer.labels_))
labels
# Out:
# [-1]

# %%
sum = 0
for i in set(labels):
    findtag = (df_raw["cluster"] == labels[i])
    #sum += len(df_raw[findtag])
    print(len(df_raw[findtag]))
print(sum)
# Out:
# 0
# 0

# %%
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_clusters_
# Out:
# 0

# %% [markdown]
# # plot

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.cluster as cluster
import time
# %matplotlib inline
sns.set_context('poster')
sns.set_color_codes()
plot_kwds = {'alpha' : 0.25, 's' : 80, 'linewidths':0}

# %%
def plot_clusters(data, algorithm, args, kwds):
    start_time = time.time()
    labels = algorithm(*args, **kwds).fit_predict(data)
    end_time = time.time()
    palette = sns.color_palette('deep', np.unique(labels).max() + 1)
    colors = [palette[x] if x >= 0 else (0.0, 0.0, 0.0) for x in labels]
    plt.scatter(data.T[0], data.T[1], c=colors, **plot_kwds)
    frame = plt.gca()
    frame.axes.get_xaxis().set_visible(False)
    frame.axes.get_yaxis().set_visible(False)
    plt.title('Clusters found by {}'.format(str(algorithm.__name__)), fontsize=24)
    plt.text(-0.5, 0.7, 'Clustering took {:.2f} s'.format(end_time - start_time), fontsize=14)

# %%
plot_clusters(tfidf.toarray(), hdbscan.HDBSCAN, (), {'min_cluster_size':3})

# %%
#project the data into two dimensions to visualize it via t-SNE???

clusterer = hdbscan.HDBSCAN(min_cluster_size=3).fit(tfidf.toarray())
color_palette = sns.color_palette('Paired', 12)
cluster_colors = [color_palette[x] if x >= 0
                  else (0.5, 0.5, 0.5)
                  for x in clusterer.labels_]
cluster_member_colors = [sns.desaturate(x, p) for x, p in
                         zip(cluster_colors, clusterer.probabilities_)]
plt.scatter(*projection.T, s=50, linewidth=0, c=cluster_member_colors, alpha=0.25)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-298-88cac484b7a6> in <module>()
#       3 cluster_colors = [color_palette[x] if x >= 0
#       4                   else (0.5, 0.5, 0.5)
# ----> 5                   for x in clusterer.labels_]
#       6 cluster_member_colors = [sns.desaturate(x, p) for x, p in
#       7                          zip(cluster_colors, clusterer.probabilities_)]
#
# <ipython-input-298-88cac484b7a6> in <listcomp>(.0)
#       3 cluster_colors = [color_palette[x] if x >= 0
#       4                   else (0.5, 0.5, 0.5)
# ----> 5                   for x in clusterer.labels_]
#       6 cluster_member_colors = [sns.desaturate(x, p) for x, p in
#       7                          zip(cluster_colors, clusterer.probabilities_)]
#
# IndexError: list index out of range

# %%
plot_clusters(tfidf.toarray(), cluster.DBSCAN, (), {'eps':0.8})
